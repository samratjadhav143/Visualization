#         0.95039493,  0.96481908,  0.9768074 ,  0.98632961,  0.99336168,
#         0.99788585,  0.99989069,  0.99937116,  0.99632856,  0.99077057,
#         0.98271122,  0.97217086,  0.95917611,  0.94375976,  0.92596075,
#         0.905824  ,  0.88340035,  0.85874643,  0.83192446,  0.80300216,
#         0.77205257,  0.7391538 ,  0.70438892,  0.66784571,  0.62961641,
#         0.58979754,  0.54848964,  0.50579699,  0.46182738,  0.41669181,
#         0.37050423,  0.32338126,  0.27544187,  0.22680707,  0.17759967,
#         0.12794389,  0.07796509,  0.02778946, -0.02245633, -0.07264543,
#        -0.12265112, -0.17234716, -0.22160808, -0.27030952, -0.31832851,
#        -0.36554384, -0.4118363 , -0.45708901, -0.50118772, -0.54402111])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("this is my x data")
plt.ylabel("this is my y data")
plt.title("this is my title ")
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y)

# %%
x,y
# Out:
# (array([0.42715815, 0.53291671, 0.82906307, 0.98751259, 0.21928022,
#         0.91060638, 0.22343113, 0.71765207, 0.44604918, 0.15311486,
#         0.22602757, 0.21419362, 0.05836004, 0.37607099, 0.62635891,
#         0.81471867, 0.1880632 , 0.32238618, 0.60803115, 0.65016491,
#         0.42422162, 0.0829958 , 0.64091516, 0.79753094, 0.7312    ,
#         0.7259002 , 0.11325422, 0.18610182, 0.11384564, 0.41049451,
#         0.97214664, 0.21042718, 0.68462557, 0.54689114, 0.59591007,
#         0.41446275, 0.87572823, 0.54271563, 0.63856698, 0.19004147,
#         0.29580332, 0.00212582, 0.55472202, 0.48029533, 0.01084019,
#         0.08915297, 0.89736843, 0.41677819, 0.842592  , 0.82409179]),
#  array([0.71239762, 0.67511617, 0.02340385, 0.30050517, 0.48341341,
#         0.52364688, 0.90276504, 0.91390874, 0.68515833, 0.88824265,
#         0.61273563, 0.00974024, 0.27687815, 0.37184155, 0.36111502,
#         0.17453748, 0.28225309, 0.22987599, 0.90474275, 0.18653247,
#         0.79595893, 0.41648934, 0.48455904, 0.64044846, 0.22779479,
#         0.36433946, 0.34387368, 0.94374445, 0.27478555, 0.18576135,
#         0.07926842, 0.44343101, 0.80492201, 0.78808773, 0.44082306,
#         0.15606236, 0.00260661, 0.83647484, 0.30250699, 0.84766306,
#         0.73070277, 0.05278783, 0.34369365, 0.733981  , 0.92061727,
#         0.15960442, 0.17510638, 0.35082156, 0.25071084, 0.93924455]))

# %%
colours = np.random.rand(50)
sizes = 1000* np.random.rand(50)
plt.scatter(x,y , c = colours , s = sizes , alpha=.5)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("random data")
plt.colorbar(label='Color Scale')

# %%
import matplotlib.pyplot as plt
import numpy as np


colours = np.random.rand(50)
sizes = 1000 * np.random.rand(50)


plt.figure(figsize=(10, 6))
plt.scatter(x, y, c=colours, s=sizes, alpha=0.5, cmap='viridis')
plt.colorbar(label='Color Scale')

# अक्षरे आणि शीर्षक द्या
plt.xlabel("x अक्ष")
plt.ylabel("y अक्ष")
plt.title("कसाबी डेटा")

# प्लॉटचा दृश्यपट बदला
plt.grid(True, linestyle='--', alpha=0.6)  # ग्रिड संघटनारे

# प्लॉटचा तस्विर सुरक्षित करणे
plt.savefig("scatter_plot.png", dpi=300, bbox_inches='tight')  # तस्विर सुरक्षित करण्यासाठी

# प्लॉट दाखवा
plt.show()
# Out:
# C:\Users\SAMRAT\AppData\Local\Temp\ipykernel_23816\2281720371.py:22: UserWarning: Glyph 2309 (\N{DEVANAGARI LETTER A}) missing from current font.
#   plt.savefig("scatter_plot.png", dpi=300, bbox_inches='tight')  # तस्विर सुरक्षित करण्यासाठी
# C:\Users\SAMRAT\AppData\Local\Temp\ipykernel_23816\2281720371.py:22: UserWarning: Matplotlib currently does not support Devanagari natively.
#   plt.savefig("scatter_plot.png", dpi=300, bbox_inches='tight')  # तस्विर सुरक्षित करण्यासाठी
# C:\Users\SAMRAT\AppData\Local\Temp\ipykernel_23816\2281720371.py:22: UserWarning: Glyph 2325 (\N{DEVANAGARI LETTER KA}) missing from current font.
#   plt.savefig("scatter_plot.png", dpi=300, bbox_inches='tight')  # तस्विर सुरक्षित करण्यासाठी
# C:\Users\SAMRAT\AppData\Local\Temp\ipykernel_23816\2281720371.py:22: UserWarning: Glyph 2381 (\N{DEVANAGARI SIGN VIRAMA}) missing from current font.
#   plt.savefig("scatter_plot.png", dpi=300, bbox_inches='tight')  # तस्विर सुरक्षित करण्यासाठी
# C:\Users\SAMRAT\AppData\Local\Temp\ipykernel_23816\2281720371.py:22: UserWarning: Glyph 2359 (\N{DEVANAGARI LETTER SSA}) missing from current font.
#   plt.savefig("scatter_plot.png", dpi=300, bbox_inches='tight')  # तस्विर सुरक्षित करण्यासाठी
# C:\Users\SAMRAT\AppData\Local\Temp\ipykernel_23816\2281720371.py:22: UserWarning: Glyph 2360 (\N{DEVANAGARI LETTER SA}) missing from current font.
#   plt.savefig("scatter_plot.png", dpi=300, bbox_inches='tight')  # तस्विर सुरक्षित करण्यासाठी
# C:\Users\SAMRAT\AppData\Local\Temp\ipykernel_23816\2281720371.py:22: UserWarning: Glyph 2366 (\N{DEVANAGARI VOWEL SIGN AA}) missing from current font.
#   plt.savefig("scatter_plot.png", dpi=300, bbox_inches='tight')  # तस्विर सुरक्षित करण्यासाठी
# C:\Users\SAMRAT\AppData\Local\Temp\ipykernel_23816\2281720371.py:22: UserWarning: Glyph 2348 (\N{DEVANAGARI LETTER BA}) missing from current font.
#   plt.savefig("scatter_plot.png", dpi=300, bbox_inches='tight')  # तस्विर सुरक्षित करण्यासाठी
# C:\Users\SAMRAT\AppData\Local\Temp\ipykernel_23816\2281720371.py:22: UserWarning: Glyph 2368 (\N{DEVANAGARI VOWEL SIGN II}) missing from current font.
#   plt.savefig("scatter_plot.png", dpi=300, bbox_inches='tight')  # तस्विर सुरक्षित करण्यासाठी
# C:\Users\SAMRAT\AppData\Local\Temp\ipykernel_23816\2281720371.py:22: UserWarning: Glyph 2337 (\N{DEVANAGARI LETTER DDA}) missing from current font.
#   plt.savefig("scatter_plot.png", dpi=300, bbox_inches='tight')  # तस्विर सुरक्षित करण्यासाठी
# C:\Users\SAMRAT\AppData\Local\Temp\ipykernel_23816\2281720371.py:22: UserWarning: Glyph 2375 (\N{DEVANAGARI VOWEL SIGN E}) missing from current font.
#   plt.savefig("scatter_plot.png", dpi=300, bbox_inches='tight')  # तस्विर सुरक्षित करण्यासाठी
# C:\Users\SAMRAT\AppData\Local\Temp\ipykernel_23816\2281720371.py:22: UserWarning: Glyph 2335 (\N{DEVANAGARI LETTER TTA}) missing from current font.
#   plt.savefig("scatter_plot.png", dpi=300, bbox_inches='tight')  # तस्विर सुरक्षित करण्यासाठी
# C:\Users\SAMRAT\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 2309 (\N{DEVANAGARI LETTER A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMRAT\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Matplotlib currently does not support Devanagari natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMRAT\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 2325 (\N{DEVANAGARI LETTER KA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMRAT\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 2381 (\N{DEVANAGARI SIGN VIRAMA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMRAT\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 2359 (\N{DEVANAGARI LETTER SSA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMRAT\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 2360 (\N{DEVANAGARI LETTER SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMRAT\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 2366 (\N{DEVANAGARI VOWEL SIGN AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMRAT\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 2348 (\N{DEVANAGARI LETTER BA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMRAT\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 2368 (\N{DEVANAGARI VOWEL SIGN II}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMRAT\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 2337 (\N{DEVANAGARI LETTER DDA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMRAT\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 2375 (\N{DEVANAGARI VOWEL SIGN E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMRAT\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 2335 (\N{DEVANAGARI LETTER TTA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
x = ['a' , 'b','c','d','e']

# %%
y = np.random.rand(5)
plt.bar(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("bar plot")
# Out:
# Text(0.5, 1.0, 'bar plot')

# %%
y
# Out:
# array([0.29826624, 0.41783424, 0.2673296 , 0.05707474, 0.0154268 ])

# %%
plt.barh(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("bar plot")
# Out:
# Text(0.5, 1.0, 'bar plot')

# %%
plt.figure(figsize=(6,2))
plt.plot(x,y,'--r')
plt.xlabel("this is my x data")
plt.ylabel("this is my y data")
plt.title("this is my title ")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.plot(x, y, '--r', label='Data')
plt.xlabel("X-Axis Label")
plt.ylabel("Y-Axis Label")
plt.title("Professional Plot Title")
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colours = np.random.rand(50)
sizes = 1000* np.random.rand(50)
plt.scatter(x,y , c = '#A64D13' , s = sizes , alpha=.5 , marker='v')
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("random data")
# Out:
# Text(0.5, 1.0, 'random data')

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colours = np.random.rand(50)
sizes = 1000 * np.random.rand(50)

plt.scatter(x, y, c='#A64D13', s=sizes, alpha=0.5, marker='o')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.title("Random Data")

plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colours = np.random.rand(50)
sizes = 1000 * np.random.rand(50)

plt.scatter(x, y, c='blue', s=sizes, alpha=0.5, marker='v')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.title("Random Data")

plt.show()

# %%
pip install kivy
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement kivy.app (from versions: none)
# ERROR: No matching distribution found for kivy.app
